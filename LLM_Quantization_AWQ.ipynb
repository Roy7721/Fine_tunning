# %%
pip -q install -U autoawq transformers accelerate
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.3/74.3 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for autoawq (setup.py) ... done

# %%
# import torch
# from awq import AutoAWQForCausalLM
# from transformers import AutoTokenizer, AutoConfig
# import gc
# import os

# # Configure environment
# os.environ["TOKENIZERS_PARALLELISM"] = "false"

# base_model = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

# print("Checking PyTorch and CUDA versions...")
# print(f"PyTorch version: {torch.__version__}")
# print(f"CUDA available: {torch.cuda.is_available()}")
# if torch.cuda.is_available():
#     print(f"CUDA version: {torch.version.cuda}")
#     print(f"GPU: {torch.cuda.get_device_name()}")

# # Clear any existing cache
# if torch.cuda.is_available():
#     torch.cuda.empty_cache()
# gc.collect()

# print("Loading tokenizer...")
# tok = AutoTokenizer.from_pretrained(
#     base_model,
#     use_fast=True,
#     trust_remote_code=True
# )
# if tok.pad_token is None:
#     tok.pad_token = tok.eos_token

# print("Loading model...")
# # Load model with specific configurations to avoid attention issues
# mdl = AutoAWQForCausalLM.from_pretrained(
#     base_model,
#     low_cpu_mem_usage=True,
#     use_cache=False,
#     trust_remote_code=True,
#     torch_dtype=torch.float16,  # Use fp16 explicitly
#     device_map={"": 0} if torch.cuda.is_available() else "cpu"  # More specific device mapping
# )

# # Set model to eval mode
# mdl.eval()

# # AWQ quantization config
# quant_config = {
#     "zero_point": True,
#     "q_group_size": 128,
#     "w_bit": 4,
#     "version": "GEMM"
# }

# # Create more diverse and shorter calibration data
# print("Preparing calibration data...")
# calib_texts = [
#     "The quick brown fox jumps over the lazy dog.",
#     "Machine learning models process data efficiently.",
#     "Natural language understanding is advancing rapidly.",
#     "Deep neural networks learn complex patterns.",
#     "Artificial intelligence transforms technology.",
#     "Computer vision recognizes objects accurately.",
#     "Robotics integrates sensors and actuators.",
#     "Algorithm optimization improves performance significantly.",
#     "Data science extracts meaningful insights.",
#     "Software engineering creates reliable systems."
# ] * 10  # 100 samples total

# print("Starting quantization...")
# try:
#     # Use minimal configuration to avoid batch size issues
#     mdl.quantize(
#         tok,
#         quant_config=quant_config,
#         calib_data=calib_texts,
#         max_calib_seq_len=128,     # Reduced sequence length
#         max_calib_samples=50,      # Reduced sample count
#         n_parallel_calib_samples=1 # Keep sequential processing
#     )

#     print("Quantization completed successfully!")

#     # Save the quantized model
#     out_dir = "tinyllama-1.1b-awq"
#     print(f"Saving model to {out_dir}...")

#     mdl.save_quantized(out_dir, safetensors=True)
#     tok.save_pretrained(out_dir)

#     # Save config
#     config = AutoConfig.from_pretrained(base_model, trust_remote_code=True)
#     config.save_pretrained(out_dir)

#     print(f"Model successfully quantized and saved to {out_dir}")

# except Exception as e:
#     print(f"Quantization failed with error: {str(e)}")
#     print("\nTrying alternative approach with different model loading...")

#     # Alternative approach: Load model differently
#     del mdl
#     if torch.cuda.is_available():
#         torch.cuda.empty_cache()
#     gc.collect()

#     try:
#         # Try loading without device_map first
#         mdl = AutoAWQForCausalLM.from_pretrained(
#             base_model,
#             low_cpu_mem_usage=True,
#             trust_remote_code=True,
#             use_cache=False
#         )

#         # Move to device manually if CUDA is available
#         if torch.cuda.is_available():
#             mdl = mdl.cuda()

#         mdl.eval()

#         # Try with even smaller calibration parameters
#         print("Attempting quantization with minimal parameters...")
#         mdl.quantize(
#             tok,
#             quant_config=quant_config,
#             calib_data=calib_texts[:20],  # Only use first 20 samples
#             max_calib_seq_len=64,         # Even smaller sequence length
#             max_calib_samples=20,         # Minimal samples
#             n_parallel_calib_samples=1
#         )

#         out_dir = "tinyllama-1.1b-awq"
#         mdl.save_quantized(out_dir, safetensors=True)
#         tok.save_pretrained(out_dir)

#         config = AutoConfig.from_pretrained(base_model, trust_remote_code=True)
#         config.save_pretrained(out_dir)

#         print(f"Model successfully quantized with alternative approach and saved to {out_dir}")

#     except Exception as e2:
#         print(f"Alternative approach also failed: {str(e2)}")
#         print("\nConsider using a pre-quantized model instead:")
#         print("TheBloke/TinyLlama-1.1B-Chat-v1.0-AWQ")

# finally:
#     # Cleanup
#     if torch.cuda.is_available():
#         torch.cuda.empty_cache()
#     gc.collect()
# Out:
# Checking PyTorch and CUDA versions...
# PyTorch version: 2.6.0+cu124
# CUDA available: True
# CUDA version: 12.4
# GPU: Tesla T4
# Loading tokenizer...
# Loading model...
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Preparing calibration data...
# Starting quantization...
# AWQ:   0%|          | 0/22 [00:00<?, ?it/s]
# Quantization failed with error: output with shape [1, 32, 128, 128] doesn't match the broadcast shape [3, 32, 128, 128]
#
# Trying alternative approach with different model loading...
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# Attempting quantization with minimal parameters...
# AWQ:   0%|          | 0/22 [00:00<?, ?it/s]
# Alternative approach also failed: output with shape [1, 32, 64, 64] doesn't match the broadcast shape [2, 32, 64, 64]
#
# Consider using a pre-quantized model instead:
# TheBloke/TinyLlama-1.1B-Chat-v1.0-AWQ

# %%
import torch
from awq import AutoAWQForCausalLM
from transformers import AutoTokenizer, AutoConfig
import gc
import os

# Configure environment
os.environ["TOKENIZERS_PARALLELISM"] = "false"

base_model = "TinyLlama/TinyLlama-1.1B-Chat-v1.0"

print("Checking PyTorch and CUDA versions...")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"CUDA version: {torch.version.cuda}")
    print(f"GPU: {torch.cuda.get_device_name()}")

# Clear any existing cache
if torch.cuda.is_available():
    torch.cuda.empty_cache()
gc.collect()

print("Loading tokenizer...")
tok = AutoTokenizer.from_pretrained(
    base_model,
    use_fast=True,
    trust_remote_code=True
)
if tok.pad_token is None:
    tok.pad_token = tok.eos_token

print("Loading model...")
# Load model with specific configurations to avoid attention issues
mdl = AutoAWQForCausalLM.from_pretrained(
    base_model,
    low_cpu_mem_usage=True,
    use_cache=False,
    trust_remote_code=True,
    torch_dtype=torch.float16,  # Use fp16 explicitly
    device_map={"": 0} if torch.cuda.is_available() else "cpu"  # More specific device mapping
)

# Set model to eval mode
mdl.eval()

# AWQ quantization config
quant_config = {
    "zero_point": True,
    "q_group_size": 128,
    "w_bit": 4,
    "version": "GEMM"
}

# Create more diverse and shorter calibration data
print("Preparing calibration data...")
calib_texts = [
    "The quick brown fox jumps over the lazy dog.",
    "Machine learning models process data efficiently.",
    "Natural language understanding is advancing rapidly.",
    "Deep neural networks learn complex patterns.",
    "Artificial intelligence transforms technology.",
    "Computer vision recognizes objects accurately.",
    "Robotics integrates sensors and actuators.",
    "Algorithm optimization improves performance significantly.",
    "Data science extracts meaningful insights.",
    "Software engineering creates reliable systems."
] * 10  # 100 samples total

print("Starting quantization...")
try:
    # Use minimal configuration to avoid batch size issues
    mdl.quantize(
        tok,
        quant_config=quant_config,
        calib_data=calib_texts,
        max_calib_seq_len=128,     # Reduced sequence length
        max_calib_samples=50,      # Reduced sample count
        n_parallel_calib_samples=1 # Keep sequential processing
    )

    print("Quantization completed successfully!")

    # Save the quantized model
    out_dir = "tinyllama-1.1b-awq"
    print(f"Saving model to {out_dir}...")

    mdl.save_quantized(out_dir, safetensors=True)
    tok.save_pretrained(out_dir)

    # Save config
    config = AutoConfig.from_pretrained(base_model, trust_remote_code=True)
    config.save_pretrained(out_dir)

    print(f"Model successfully quantized and saved to {out_dir}")

except Exception as e:
    print(f"Quantization failed with error: {str(e)}")
    print("\nTrying alternative approach with different model loading...")

    # Alternative approach: Load model differently
    del mdl
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()

    try:
        # Try loading without device_map first
        mdl = AutoAWQForCausalLM.from_pretrained(
            base_model,
            low_cpu_mem_usage=True,
            trust_remote_code=True,
            use_cache=False
        )

        # Move to device manually if CUDA is available
        if torch.cuda.is_available():
            mdl = mdl.cuda()

        mdl.eval()

        # Try with even smaller calibration parameters
        print("Attempting quantization with minimal parameters...")
        mdl.quantize(
            tok,
            quant_config=quant_config,
            calib_data=calib_texts[:20],  # Only use first 20 samples
            max_calib_seq_len=64,         # Even smaller sequence length
            max_calib_samples=20,         # Minimal samples
            n_parallel_calib_samples=1
        )

        out_dir = "tinyllama-1.1b-awq"
        mdl.save_quantized(out_dir, safetensors=True)
        tok.save_pretrained(out_dir)

        config = AutoConfig.from_pretrained(base_model, trust_remote_code=True)
        config.save_pretrained(out_dir)

        print(f"Model successfully quantized with alternative approach and saved to {out_dir}")

    except Exception as e2:
        print(f"Alternative approach also failed: {str(e2)}")
        print("\nConsider using a pre-quantized model instead:")
        print("TheBloke/TinyLlama-1.1B-Chat-v1.0-AWQ")

finally:
    # Cleanup
    if torch.cuda.is_available():
        torch.cuda.empty_cache()
    gc.collect()
# Out:
# /usr/local/lib/python3.13/dist-packages/awq/__init__.py:21: DeprecationWarning:
# I have left this message as the final dev message to help you transition.
#
# Important Notice:
# - AutoAWQ is officially deprecated and will no longer be maintained.
# - The last tested configuration used Torch 2.6.0 and Transformers 4.51.3.
# - If future versions of Transformers break AutoAWQ compatibility, please report the issue to the Transformers project.
#
# Alternative:
# - AutoAWQ has been adopted by the vLLM Project: https://github.com/vllm-project/llm-compressor
#
# For further inquiries, feel free to reach out:
# - X: https://x.com/casper_hansen_
# - LinkedIn: https://www.linkedin.com/in/casper-hansen-804005170/
#
#   warnings.warn(_FINAL_DEV_MESSAGE, category=DeprecationWarning, stacklevel=1)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/torch/jit/_script.py:1488: DeprecationWarning: `torch.jit.script` is deprecated. Please switch to `torch.compile` or `torch.export`.
#   warnings.warn(
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Checking PyTorch and CUDA versions...
# PyTorch version: 2.11.0+cu128
# CUDA available: True
# CUDA version: 12.8
# GPU: Tesla T4
# Loading tokenizer...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/608 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.29k [00:00<?, ?B/s]
# tokenizer.model: reconstructing file:   0%|          |  0.00B /  500kB
# tokenizer.model: downloading bytes:           |  0.00B
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/551 [00:00<?, ?B/s]
# Loading model...
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# [transformers] `torch_dtype` is deprecated! Use `dtype` instead!
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Preparing calibration data...
# Starting quantization...
# AWQ: 100%|██████████| 22/22 [03:11<00:00,  8.71s/it]
# Quantization completed successfully!
# Saving model to tinyllama-1.1b-awq...
# Writing model shards: 0it [00:00, ?it/s]
# Model successfully quantized and saved to tinyllama-1.1b-awq

# %%
# !pip install llmcompressor
# Out:
# Collecting llmcompressor
#   Downloading llmcompressor-0.13.0-py3-none-any.whl.metadata (16 kB)
# Collecting loguru<=0.7.3,>=0.7.2 (from llmcompressor)
#   Downloading loguru-0.7.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml<=6.0.3,>=6.0.1 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (6.0.3)
# Requirement already satisfied: numpy<=2.4.6,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (2.1.3)
# Requirement already satisfied: requests<2.35.0,>=2.32.2 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (2.32.4)
# Requirement already satisfied: tqdm<=4.70.0,>=4.66.3 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (4.67.3)
# Requirement already satisfied: torch<=2.13.0,>=2.10.0 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (2.11.0+cu128)
# Collecting transformers<=5.14.1,>=5.9.0 (from llmcompressor)
#   Downloading transformers-5.14.1-py3-none-any.whl.metadata (32 kB)
# Collecting datasets<=5.0.1,>=4.8.4 (from llmcompressor)
#   Downloading datasets-5.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting auto-round<=0.14.2,>=0.14.1 (from llmcompressor)
#   Downloading auto_round-0.14.2-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: accelerate<=1.14.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (1.14.0)
# Requirement already satisfied: nvidia-ml-py<=13.610.43,>=12.560.30 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (13.610.43)
# Requirement already satisfied: pillow<13.0.0,>=10.4.0 in /usr/local/lib/python3.13/dist-packages (from llmcompressor) (11.3.0)
# Collecting compressed-tensors==0.18.0 (from llmcompressor)
#   Downloading compressed_tensors-0.18.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.13/dist-packages (from compressed-tensors==0.18.0->llmcompressor) (2.13.4)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from compressed-tensors==0.18.0->llmcompressor) (5.9.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from accelerate<=1.14.0,>=1.6.0->llmcompressor) (26.3)
# Requirement already satisfied: huggingface_hub>=0.21.0 in /usr/local/lib/python3.13/dist-packages (from accelerate<=1.14.0,>=1.6.0->llmcompressor) (1.28.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.13/dist-packages (from accelerate<=1.14.0,>=1.6.0->llmcompressor) (0.8.0)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.13/dist-packages (from auto-round<=0.14.2,>=0.14.1->llmcompressor) (9.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.13/dist-packages (from datasets<=5.0.1,>=4.8.4->llmcompressor) (3.32.4)
# Collecting pyarrow>=21.0.0 (from datasets<=5.0.1,>=4.8.4->llmcompressor)
#   Downloading pyarrow-25.0.1-cp313-cp313-manylinux_2_28_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.13/dist-packages (from datasets<=5.0.1,>=4.8.4->llmcompressor) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from datasets<=5.0.1,>=4.8.4->llmcompressor) (2.2.3)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.13/dist-packages (from datasets<=5.0.1,>=4.8.4->llmcompressor) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.13/dist-packages (from datasets<=5.0.1,>=4.8.4->llmcompressor) (4.0.1)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.13/dist-packages (from datasets<=5.0.1,>=4.8.4->llmcompressor) (0.70.16)
# Requirement already satisfied: fsspec<=2026.6.0,>=2023.1.0 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (2025.3.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<2.35.0,>=2.32.2->llmcompressor) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests<2.35.0,>=2.32.2->llmcompressor) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<2.35.0,>=2.32.2->llmcompressor) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests<2.35.0,>=2.32.2->llmcompressor) (2026.7.22)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (3.1.6)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.13/dist-packages (from torch<=2.13.0,>=2.10.0->llmcompressor) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.13/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch<=2.13.0,>=2.10.0->llmcompressor) (12.8.90)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.13/dist-packages (from transformers<=5.14.1,>=5.9.0->llmcompressor) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<=5.14.1,>=5.9.0->llmcompressor)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: typer in /usr/local/lib/python3.13/dist-packages (from transformers<=5.14.1,>=5.9.0->llmcompressor) (0.27.1)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.13/dist-packages (from cuda-bindings<13,>=12.9.4->torch<=2.13.0,>=2.10.0->llmcompressor) (1.7.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.13/dist-packages (from fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (3.14.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate<=1.14.0,>=1.6.0->llmcompressor) (8.5.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface_hub>=0.21.0->accelerate<=1.14.0,>=1.6.0->llmcompressor) (1.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->compressed-tensors==0.18.0->llmcompressor) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->compressed-tensors==0.18.0->llmcompressor) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->compressed-tensors==0.18.0->llmcompressor) (0.4.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from sympy>=1.13.3->torch<=2.13.0,>=2.10.0->llmcompressor) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->torch<=2.13.0,>=2.10.0->llmcompressor) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets<=5.0.1,>=4.8.4->llmcompressor) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets<=5.0.1,>=4.8.4->llmcompressor) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->datasets<=5.0.1,>=4.8.4->llmcompressor) (2026.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers<=5.14.1,>=5.9.0->llmcompressor) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.13/dist-packages (from typer->transformers<=5.14.1,>=5.9.0->llmcompressor) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer->transformers<=5.14.1,>=5.9.0->llmcompressor) (0.0.5)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.13/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.6.0,>=2023.1.0->datasets<=5.0.1,>=4.8.4->llmcompressor) (1.24.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas->datasets<=5.0.1,>=4.8.4->llmcompressor) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers<=5.14.1,>=5.9.0->llmcompressor) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=13.8.0->typer->transformers<=5.14.1,>=5.9.0->llmcompressor) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers<=5.14.1,>=5.9.0->llmcompressor) (0.1.2)
# Downloading llmcompressor-0.13.0-py3-none-any.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 15.2 MB/s eta 0:00:00
# Downloading compressed_tensors-0.18.0-py3-none-any.whl (224 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.0/225.0 kB 24.1 MB/s eta 0:00:00
# Downloading auto_round-0.14.2-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 53.4 MB/s eta 0:00:00
# Downloading datasets-5.0.1-py3-none-any.whl (559 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 559.1/559.1 kB 53.1 MB/s eta 0:00:00
# Downloading loguru-0.7.3-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.3 MB/s eta 0:00:00
# Downloading transformers-5.14.1-py3-none-any.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 111.3 MB/s eta 0:00:00
# Downloading pyarrow-25.0.1-cp313-cp313-manylinux_2_28_x86_64.whl (50.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 MB 19.1 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 121.0 MB/s eta 0:00:00
# Installing collected packages: pyarrow, loguru, tokenizers, datasets, transformers, compressed-tensors, auto-round, llmcompressor
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
#       Successfully uninstalled pyarrow-18.1.0
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.23.1
#     Uninstalling tokenizers-0.23.1:
#       Successfully uninstalled tokenizers-0.23.1
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.0.0
#     Uninstalling datasets-4.0.0:
#       Successfully uninstalled datasets-4.0.0
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.16.1
#     Uninstalling transformers-5.16.1:
#       Successfully uninstalled transformers-5.16.1
# Successfully installed auto-round-0.14.2 compressed-tensors-0.18.0 datasets-5.0.1 llmcompressor-0.13.0 loguru-0.7.3 pyarrow-25.0.1 tokenizers-0.22.2 transformers-5.14.1

# %%
from llmcompressor import oneshot
from llmcompressor.modifiers.transform.awq import AWQModifier   # new path
from llmcompressor.modifiers.quantization import QuantizationModifier

# %%
recipe = [
    AWQModifier(
        ignore=["lm_head"],
        scheme="W4A16_ASYM",
        targets=["Linear"],
        duo_scaling="both",
    ),
]

# %%
from llmcompressor import oneshot
from llmcompressor.modifiers.transform.awq import AWQModifier
from llmcompressor.modifiers.quantization import QuantizationModifier

recipe = [
    AWQModifier(duo_scaling="both"),                 # scaling only — no quant args
    QuantizationModifier(                            # the actual 4-bit quantization
        ignore=["lm_head"],
        scheme="W4A16_ASYM",
        targets=["Linear"],
    ),
]
print(recipe)
# Out:
# [AWQModifier(requires_calibration_data=True, index=None, group=None, start=None, end=None, update=None, initialized_=False, finalized_=False, started_=False, ended_=False, mappings=None, offload_device=not_provided, duo_scaling='both', n_grid=20), QuantizationModifier(config_groups=None, targets=['Linear'], ignore=['lm_head'], scheme='W4A16_ASYM', kv_cache_scheme=None, weight_observer=None, input_observer=None, output_observer=None, observer=None, bypass_divisibility_checks=False, requires_calibration_data=False, index=None, group=None, start=None, end=None, update=None, initialized_=False, finalized_=False, started_=False, ended_=False)]

# %%
import os
from google.colab import userdata
from huggingface_hub import login, whoami, auth_check

tok = userdata.get("HF_TOKEN_READ").strip()
os.environ["HF_TOKEN"] = tok
os.environ["HUGGING_FACE_HUB_TOKEN"] = tok
login(token=tok, add_to_git_credential=False)

print("logged in as:", whoami()["name"])
auth_check("meta-llama/Llama-3.2-3B-Instruct")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# WARNING:huggingface_hub._login:Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# logged in as: ranaroy

# %%
oneshot(
    model = 'meta-llama/Llama-3.2-3B-Instruct',
    dataset = 'open_platypus',
    output_dir = 'llm_q_model_awq',
    recipe=recipe,
    max_seq_length = 2048,
    num_calibration_samples = 512
)
# Out:
# 2026-09-05T19:56:32.9376 | __init__ | WARNING - Disabling tokenizer parallelism due to threading conflict between FastTokenizer and Datasets. Set TOKENIZERS_PARALLELISM=false to suppress this warning.
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# Tokenizing:   0%|          | 0/24926 [00:00<?, ? examples/s]
# Adding labels:   0%|          | 0/24926 [00:00<?, ? examples/s]
# 2026-09-05T19:58:06.1395 | get_processed_dataset | WARNING - No split was specified, but a multi-split dataset was loaded. Falling back to the 'train' split for calibration.
# 2026-09-05T19:58:06.1437 | reset | INFO - Compression lifecycle reset
# 2026-09-05T19:58:06.1792 | from_modifiers | INFO - Creating recipe from modifiers
# 2026-09-05T19:58:06.1800 | on_initialize | INFO - No AWQModifier.mappings provided, inferring from model...
# Applying quantization config: 100%|██████████| 196/196 [00:00<00:00, 6642.56it/s]
# 2026-09-05T19:58:06.2213 | initialize | INFO - Compression lifecycle initialized for 2 modifiers
# 2026-09-05T19:58:06.2223 | IndependentPipeline | INFO - Inferred `SequentialPipeline` for `AWQModifier`
# W0905 19:58:09.661000 21831 torch/fx/_symbolic_trace.py:53] is_fx_tracing will return true for both fx.symbolic_trace and torch.export. Please use is_fx_tracing_symbolic_tracing() for specifically fx.symbolic_trace or torch.compiler.is_compiling() for specifically torch.export/compile.
# 2026-09-05T19:58:09.9230 | _set_resolved_mappings | WARNING - 28 mappings were skipped due to incompatible shapes. Set logging to DEBUG to view full list.
# Preparing cache: 100%|██████████| 512/512 [00:00<00:00, 653.51it/s]
# (1/29): Calibrating: 100%|██████████| 512/512 [00:01<00:00, 461.05it/s]
# Smoothing: 0it [00:00, ?it/s]
# (1/29): Propagating: 100%|██████████| 512/512 [00:14<00:00, 35.62it/s]
# (2/29): Calibrating:  39%|███▉      | 201/512 [00:38<00:59,  5.20it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# /usr/local/lib/python3.13/dist-packages/llmcompressor/pipelines/sequential/helpers.py in wrapper(*args, **kwargs)
#     487         try:
# --> 488             return func(*args, **kwargs)
#     489         except torch.OutOfMemoryError as e:
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/pipelines/sequential/pipeline.py in __call__(model, dataloader, dataset_args)
#     152                         session.state.current_batch_idx = batch_idx
# --> 153                         outputs = subgraph.forward(model, **inputs)
#     154
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/pipelines/sequential/helpers.py in forward(self, *args, **kwargs)
#      63         with append_autowrap_source_on_fail():
# ---> 64             return forward_fn(*args, **kwargs)
#      65
#
# <string> in forward(self, model_rotary_emb, getitem_2, getitem, wrapped_4)
#
# /usr/local/lib/python3.13/dist-packages/transformers/modeling_layers.py in __call__(self, *args, **kwargs)
#     109             return self._gradient_checkpointing_func(partial(super().__call__, **kwargs), *args)
# --> 110         return super().__call__(*args, **kwargs)
#     111
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1789                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1790             return forward_call(*args, **kwargs)
#    1791
#
# /usr/local/lib/python3.13/dist-packages/compressed_tensors/offload/module.py in forward(self, *args, **kwargs)
#      57
# ---> 58         return self._original_forward_func(self, *args, **kwargs)
#      59
#
# /usr/local/lib/python3.13/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, attention_mask, position_ids, past_key_values, use_cache, position_embeddings, **kwargs)
#     315         # Self Attention
# --> 316         hidden_states, _ = self.self_attn(
#     317             hidden_states=hidden_states,
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1778         else:
# -> 1779             return self._call_impl(*args, **kwargs)
#    1780
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1884         try:
# -> 1885             return inner()
#    1886         except Exception:
#
# /usr/local/lib/python3.13/dist-packages/torch/nn/modules/module.py in inner()
#    1832
# -> 1833             result = forward_call(*args, **kwargs)
#    1834             if _global_forward_hooks or self._forward_hooks:
#
# /usr/local/lib/python3.13/dist-packages/compressed_tensors/offload/module.py in forward(self, *args, **kwargs)
#      57
# ---> 58         return self._original_forward_func(self, *args, **kwargs)
#      59
#
# /usr/local/lib/python3.13/dist-packages/transformers/models/llama/modeling_llama.py in forward(self, hidden_states, position_embeddings, attention_mask, past_key_values, **kwargs)
#     275
# --> 276         attn_output, attn_weights = attention_interface(
#     277             self,
#
# /usr/local/lib/python3.13/dist-packages/transformers/integrations/sdpa_attention.py in sdpa_attention_forward(module, query, key, value, attention_mask, dropout, scaling, is_causal, position_bias, **kwargs)
#     153
# --> 154     attn_output = torch.nn.functional.scaled_dot_product_attention(
#     155         query,
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 384.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 317.81 MiB is free. Including non-PyTorch memory, this process has 14.25 GiB memory in use. Of the allocated memory 12.76 GiB is allocated by PyTorch, and 1.36 GiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)
#
# The above exception was the direct cause of the following exception:
#
# OutOfMemoryError                          Traceback (most recent call last)
# /tmp/ipykernel_21831/3700644200.py in <cell line: 0>()
# ----> 1 oneshot(
#       2     model = 'meta-llama/Llama-3.2-3B-Instruct',
#       3     dataset = 'open_platypus',
#       4     output_dir = 'llm_q_model_awq',
#       5     recipe=recipe,
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/entrypoints/oneshot.py in oneshot(model, config_name, tokenizer, processor, precision, tie_word_embeddings, trust_remote_code_model, save_compressed, model_revision, recipe, recipe_args, clear_sparse_session, stage, dataset, dataset_config_name, dataset_path, splits, batch_size, data_collator, num_calibration_samples, shuffle_calibration_samples, max_seq_length, pad_to_max_length, text_column, concatenate_data, streaming, overwrite_cache, preprocessing_num_workers, dataloader_num_workers, min_tokens_per_module, moe_calibrate_all_experts, pipeline, tracing_ignore, sequential_targets, sequential_offload_device, quantization_aware_calibration, sequential_prefetch, output_dir, log_dir, enable_compile, **kwargs)
#     467     }
#     468     one_shot = Oneshot(**local_args, **kwargs)
# --> 469     one_shot()
#     470
#     471     return one_shot.model
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/entrypoints/oneshot.py in __call__(self)
#     199             self.dataset_args, self.processor
#     200         )
# --> 201         self.apply_recipe_modifiers(
#     202             calibration_dataloader=calibration_dataloader,
#     203             recipe_stage=self.recipe_args.stage,
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/entrypoints/oneshot.py in apply_recipe_modifiers(self, calibration_dataloader, recipe_stage)
#     262             )
#     263
# --> 264             pipeline(
#     265                 self.model,
#     266                 calibration_dataloader,
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/pipelines/independent/pipeline.py in __call__(model, dataloader, dataset_args)
#      43                 _logger.info(f"Inferred `{pipeline_name}` for `{mod_type}`")
#      44
# ---> 45                 pipeline(model, dataloader, dataset_args)
#      46
#      47                 # restore modifiers on exit so model can be compressed based on recipe
#
# /usr/local/lib/python3.13/dist-packages/llmcompressor/pipelines/sequential/helpers.py in wrapper(*args, **kwargs)
#     488             return func(*args, **kwargs)
#     489         except torch.OutOfMemoryError as e:
# --> 490             raise torch.OutOfMemoryError(
#     491                 "Sequential pipeline ran out of memory. "
#     492                 "Please consider choosing a smaller module for `sequential_targets`, "
#
# OutOfMemoryError: Sequential pipeline ran out of memory. Please consider choosing a smaller module for `sequential_targets`, ex. 'Linear' for dense models. For MoE models with untraceable attention, use the attention module and individual expert class instead, ex. sequential_targets=['AttentionClass', 'ExpertClass'] with sequential_targets_per_subgraph set to batch multiple experts per subgraph and reduce memory overhead.
